# %%
import prep as p
import matplotlib.pyplot as plt

# %%
# Data Preparation and Cleaning
df = p.prepared_df()
df.head()
# Out:
#        ID  Age Nationality  Overall  Potential                 Club  \
# 0  158023   31   Argentina       94         94         FC Barcelona
# 1   20801   33    Portugal       94         94             Juventus
# 2  190871   26      Brazil       92         93  Paris Saint-Germain
# 3  193080   27       Spain       91         93    Manchester United
# 4  192985   27     Belgium       91         92      Manchester City
#
#    International Reputation  Weak Foot  Skill Moves  Jersey Number  \
# 0                       5.0        4.0          4.0           10.0
# 1                       5.0        4.0          5.0            7.0
# 2                       5.0        5.0          5.0           10.0
# 3                       4.0        3.0          1.0            1.0
# 4                       4.0        5.0          4.0            7.0
#
#         ...       GKPositioning GKReflexes Inches  num_position  \
# 0       ...                14.0        8.0     67             3
# 1       ...                14.0       11.0     74             3
# 2       ...                15.0       11.0     69             3
# 3       ...                88.0       94.0     76             0
# 4       ...                10.0       13.0     71             2
#
#    enum_d_work_rate  enum_o_work_rate  norm_wage  norm_value  total_stats  \
# 0                 1                 1      565.0    110500.0       2244.0
# 1                 0                 2      405.0     77000.0       2265.0
# 2                 1                 2      290.0    118500.0       2178.0
# 3                 1                 1      260.0     72000.0        444.0
# 4                 2                 2      355.0    102000.0       2313.0
#
#    power_foot_num
# 0               1
# 1               0
# 2               0
# 3               0
# 4               0
#
# [5 rows x 55 columns]

# %%
plt.figure(figsize=(12,8))
goalkeepers = df[df.num_position == 0]
fielders = df[df.num_position != 0]
plt.scatter(goalkeepers['total_stats'] * 5, goalkeepers['norm_wage'])
plt.scatter(fielders['total_stats'], fielders['norm_wage'], alpha=.2)

# %%
plt.figure(figsize=(12,8))
plt.scatter(df['norm_value'], df['norm_wage'])

# %%
plt.figure(figsize=(12,8))
right = df[df.power_foot_num == 0]
left = df[df.power_foot_num == 1]
plt.scatter(right['Overall'], right['norm_wage'],color='green', alpha=.4, label='Right Foot')
plt.scatter(left['Overall'], left['norm_wage'],color='orange', alpha=.3, label='Left Foot')
plt.legend()

# %%
countries = df.groupby('Nationality')
countries.size()
